# %%
import sys
sys.path.append('../')  # add parent directory to the system path
from utils_data import *
from utils_model import *

# %%
# prepare the paths
root_name = "Research"
train_path, test_path, val_path = make_data_path(root_name=root_name)
print(train_path)
# Out:
# /home/hoangng/Projects/Bird_classification/Research/input/data/train

# %%
print( f"Number of classes: {len(os.listdir(train_path))}" )
# Out:
# Number of classes: 524

# %%
figure = visualize_images(train_path, 3, 3) # visualize 3x3 random images

file_path = "../input/viz"
file_name = "image_visualization.jpg"
save_plot(figure, file_name, file_path)
